# %%
import pandas as pd

# %%
df_test = pd.read_csv('/content/drive/MyDrive/expts_emnlp23/twitter-ynx2/setting_c/TE_c.csv')
df_test=df_test.rename(columns={"gold_adj": "gold"})

# %%
df_pred=pd.read_csv('/content/drive/MyDrive/expts_emnlp23/results/B_boolq+tuning.csv')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true = df_test['gold'], y_pred = df_pred['gold']))
# Out:
#               precision    recall  f1-score   support
#
#            n       0.58      0.66      0.62       177
#           pn       0.00      0.00      0.00        32
#           py       0.55      0.12      0.19        51
#           uk       0.41      0.56      0.48        96
#            y       0.68      0.73      0.70       244
#
#     accuracy                           0.59       600
#    macro avg       0.44      0.41      0.40       600
# weighted avg       0.56      0.59      0.56       600
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
